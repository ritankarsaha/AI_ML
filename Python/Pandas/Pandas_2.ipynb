# %%
import pandas as pd
df = pd.read_csv('EmployeeSampleData/Employee Sample Data.csv', encoding='ISO-8859-1',header=None,names=["Roll","Name","Job","Dept","Unit","Gender","Ethnicity","Age","Hiring Data","Salary","Bonus","Country","City","Exit"])
df
# Out:
#         Roll             Name                       Job        Dept  \
# 0       EEID        Full Name                 Job Title  Department
# 1     E02387      Emily Davis                Sr. Manger          IT
# 2     E04105    Theodore Dinh       Technical Architect          IT
# 3     E02572     Luna Sanders                  Director     Finance
# 4     E02832  Penelope Jordan  Computer Systems Manager          IT
# ...      ...              ...                       ...         ...
# 996   E03094     Wesley Young               Sr. Analyst   Marketing
# 997   E01909     Lillian Khan                   Analyst     Finance
# 998   E04398      Oliver Yang                  Director   Marketing
# 999   E02521      Lily Nguyen               Sr. Analyst     Finance
# 1000  E03545      Sofia Cheng            Vice President  Accounting
#
#                         Unit  Gender  Ethnicity  Age Hiring Data  \
# 0              Business Unit  Gender  Ethnicity  Age   Hire Date
# ...

# %%
import pandas as pd
df1 = pd.read_csv('EmployeeSampleData/Employee Sample Data.csv', encoding='ISO-8859-1',header=None,nrows=3)
df1
# Out:
#        0              1                    2           3   \
# 0    EEID      Full Name            Job Title  Department
# 1  E02387    Emily Davis           Sr. Manger          IT
# 2  E04105  Theodore Dinh  Technical Architect          IT
#
#                        4       5          6    7           8              9   \
# 0           Business Unit  Gender  Ethnicity  Age   Hire Date  Annual Salary
# 1  Research & Development  Female      Black   55    4/8/2016      $141,604
# 2           Manufacturing    Male      Asian   59  11/29/1997       $99,975
#
#         10             11         12          13
# 0  Bonus %        Country       City   Exit Date
# 1     15%   United States    Seattle  10/16/2021
# 2      0%           China  Chongqing         NaN
